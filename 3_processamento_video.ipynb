# %%
import os

# %%
from include.utils import detectar_video
from ultralytics import YOLO

# %%
current_dir = os.getcwd()

caminho_video_original = os.path.join(current_dir, "videos", "video.mp4") # Caminho do video que será processado

caminho_modelo = os.path.join(current_dir, 'modelo', 'best.pt')  # Diretório do modelo treinado

modelo = YOLO(caminho_modelo)
'''
Para testar com o modelo funcional:
modelo = YOLO('modelo-funcional/weights/best.pt')
'''
# Out:
# "\nPara testar com o modelo funcional:\nmodelo = YOLO('modelo-funcional/weights/best.pt')\n"

# %%
results_video = detectar_video(caminho_video_original, modelo, 0.3, 0.7, 640, False, True, False, False, False, True)

# %%
results_video
# Out:
# <generator object BasePredictor.stream_inference at 0x0000024E9E989000>

# %%
for result in results_video:
    # Alerta
    pass
# Out:
# video 1/1 (frame 1/1264) C:\Users\Pichau\PycharmProjects\HACKATHON-MAIN\Hackathon\videos\video.mp4: 384x640 4 knifes, 33.2ms
# video 1/1 (frame 2/1264) C:\Users\Pichau\PycharmProjects\HACKATHON-MAIN\Hackathon\videos\video.mp4: 384x640 4 knifes, 15.6ms
# video 1/1 (frame 3/1264) C:\Users\Pichau\PycharmProjects\HACKATHON-MAIN\Hackathon\videos\video.mp4: 384x640 4 knifes, 15.6ms
# video 1/1 (frame 4/1264) C:\Users\Pichau\PycharmProjects\HACKATHON-MAIN\Hackathon\videos\video.mp4: 384x640 5 knifes, 0.0ms
# video 1/1 (frame 5/1264) C:\Users\Pichau\PycharmProjects\HACKATHON-MAIN\Hackathon\videos\video.mp4: 384x640 5 knifes, 0.0ms
# video 1/1 (frame 6/1264) C:\Users\Pichau\PycharmProjects\HACKATHON-MAIN\Hackathon\videos\video.mp4: 384x640 5 knifes, 15.6ms
# video 1/1 (frame 7/1264) C:\Users\Pichau\PycharmProjects\HACKATHON-MAIN\Hackathon\videos\video.mp4: 384x640 6 knifes, 15.6ms
# ...
